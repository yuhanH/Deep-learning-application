# %%
from __future__ import print_function, division
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
import pdb
plt.ion()

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(299),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(299),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

data_dir = 'images/multi_all_hist'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=6,
                                             shuffle=True, num_workers=8)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
def train_model(model, criterion, optimizer, scheduler, label_set, label_class, num_epochs=25):
    since = time.time()
    all_acc = []
    all_loss = []
    all_sens = {key: []  for key in label_set}
    all_spec = {key: []  for key in label_set}
 
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    
    positive_true = dict
    negative_true = dict()
    positive_pred = dict()
    negative_pred = dict()
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0
            positive_true = {key: 0 for key in label_set}
            negative_true = {key: 0 for key in label_set}
            
            positive_pred = {key: 0 for key in label_set}
            negative_pred = {key: 0 for key in label_set}
           
            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
                for key in positive_true:
                    positive_true[key] += torch.sum(labels.data == key)
                    negative_true[key] += torch.sum(labels.data != key)
                    preds_1 = preds == key
                    true_1 = labels.data == key
                    preds_0 = preds != key
                    true_0 = labels.data != key
                    
                    positive_pred[key] += torch.sum( preds_1 * true_1)
                    negative_pred[key] += torch.sum(preds_0 * true_0)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            all_acc.append(epoch_acc)
            all_loss.append(epoch_loss)
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
            phase, epoch_loss, epoch_acc))
            #pdb.set_trace()
            for key in positive_true:
                epoch_sensitive = positive_pred[key].double() / positive_true[key]
                epoch_specificity = negative_pred[key].double()/ negative_true[key]
                all_sens[key].append(epoch_sensitive )
                all_spec[key].append(epoch_specificity )
                
                print('{} {} Sensitivity: {:.4f} specificity: {:.4f}'.format(
            phase,label_class[key], epoch_sensitive, epoch_specificity))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, all_acc, all_sens,all_spec

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
#model_ft = models.resnet18(pretrained=True)
model_ft = models.inception_v3(pretrained=False)
model_ft.aux_logits=False


num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 4)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft, acc, sens, spec = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs= 20, label_set = [0, 1, 2, 3  ], label_class = class_names )
# Out:
# Epoch 0/19
# ----------
# train Loss: 1.3061 Acc: 0.3829
# train bacteria Sensitivity: 0.3917 specificity: 0.7442
# train covid Sensitivity: 0.4967 specificity: 0.8227
# train influenza Sensitivity: 0.3097 specificity: 0.7683
# train normal Sensitivity: 0.3355 specificity: 0.8409
# val Loss: 1.0623 Acc: 0.5918
# val bacteria Sensitivity: 0.0000 specificity: 1.0000
# val covid Sensitivity: 0.8475 specificity: 0.9279
# val influenza Sensitivity: 0.6800 specificity: 0.6406
# val normal Sensitivity: 0.8261 specificity: 0.8737
#
# Epoch 1/19
# ----------
# train Loss: 0.9606 Acc: 0.5812
# train bacteria Sensitivity: 0.4490 specificity: 0.8310
# train covid Sensitivity: 0.8033 specificity: 0.9211
# train influenza Sensitivity: 0.3548 specificity: 0.8230
# train normal Sensitivity: 0.7309 specificity: 0.8658
# val Loss: 0.7764 Acc: 0.6180
# val bacteria Sensitivity: 0.0938 specificity: 0.9901
# val covid Sensitivity: 0.9153 specificity: 0.9712
# val influenza Sensitivity: 0.8133 specificity: 0.5521
# val normal Sensitivity: 0.6377 specificity: 0.9596
#
# Epoch 2/19
# ----------
# train Loss: 0.8751 Acc: 0.6343
# train bacteria Sensitivity: 0.5000 specificity: 0.8310
# train covid Sensitivity: 0.8700 specificity: 0.9503
# train influenza Sensitivity: 0.4419 specificity: 0.8339
# train normal Sensitivity: 0.7375 specificity: 0.8961
# val Loss: 0.8686 Acc: 0.6142
# val bacteria Sensitivity: 0.1562 specificity: 0.9310
# val covid Sensitivity: 0.8475 specificity: 0.9856
# val influenza Sensitivity: 0.8000 specificity: 0.5938
# val normal Sensitivity: 0.6377 specificity: 0.9596
#
# Epoch 3/19
# ----------
# train Loss: 0.8072 Acc: 0.6555
# train bacteria Sensitivity: 0.4968 specificity: 0.8485
# train covid Sensitivity: 0.8900 specificity: 0.9557
# train influenza Sensitivity: 0.4516 specificity: 0.8317
# train normal Sensitivity: 0.7973 specificity: 0.9037
# val Loss: 0.6472 Acc: 0.7004
# val bacteria Sensitivity: 0.4531 specificity: 0.8966
# val covid Sensitivity: 0.9492 specificity: 0.9808
# val influenza Sensitivity: 0.5333 specificity: 0.8021
# val normal Sensitivity: 0.8986 specificity: 0.9141
#
# Epoch 4/19
# ----------
# train Loss: 0.7354 Acc: 0.6702
# train bacteria Sensitivity: 0.5255 specificity: 0.8288
# train covid Sensitivity: 0.9033 specificity: 0.9600
# train influenza Sensitivity: 0.4516 specificity: 0.8536
# train normal Sensitivity: 0.8140 specificity: 0.9167
# val Loss: 0.8129 Acc: 0.6479
# val bacteria Sensitivity: 0.0000 specificity: 1.0000
# val covid Sensitivity: 0.8475 specificity: 0.9904
# val influenza Sensitivity: 0.8000 specificity: 0.6042
# val normal Sensitivity: 0.9130 specificity: 0.9192
#
# Epoch 5/19
# ----------
# train Loss: 0.7435 Acc: 0.6906
# train bacteria Sensitivity: 0.5446 specificity: 0.8518
# train covid Sensitivity: 0.8867 specificity: 0.9697
# train influenza Sensitivity: 0.5226 specificity: 0.8459
# train normal Sensitivity: 0.8206 specificity: 0.9188
# val Loss: 0.6113 Acc: 0.7566
# val bacteria Sensitivity: 0.7500 specificity: 0.8719
# val covid Sensitivity: 0.9831 specificity: 0.9567
# val influenza Sensitivity: 0.4133 specificity: 0.9271
# val normal Sensitivity: 0.9420 specificity: 0.9192
#
# Epoch 6/19
# ----------
# train Loss: 0.7754 Acc: 0.6669
# train bacteria Sensitivity: 0.5255 specificity: 0.8452
# train covid Sensitivity: 0.8967 specificity: 0.9632
# train influenza Sensitivity: 0.4581 specificity: 0.8240
# train normal Sensitivity: 0.8007 specificity: 0.9221
# val Loss: 2.0602 Acc: 0.4719
# val bacteria Sensitivity: 0.0156 specificity: 0.9951
# val covid Sensitivity: 1.0000 specificity: 0.4952
# val influenza Sensitivity: 0.0000 specificity: 1.0000
# val normal Sensitivity: 0.9565 specificity: 0.8232
#
# Epoch 7/19
# ----------
# train Loss: 0.6540 Acc: 0.7200
# train bacteria Sensitivity: 0.5860 specificity: 0.8749
# train covid Sensitivity: 0.9467 specificity: 0.9427
# train influenza Sensitivity: 0.5032 specificity: 0.8885
# train normal Sensitivity: 0.8571 specificity: 0.9199
# val Loss: 0.5729 Acc: 0.7341
# val bacteria Sensitivity: 0.6250 specificity: 0.8621
# val covid Sensitivity: 0.9661 specificity: 0.9615
# val influenza Sensitivity: 0.4400 specificity: 0.8958
# val normal Sensitivity: 0.9565 specificity: 0.9242
#
# Epoch 8/19
# ----------
# train Loss: 0.6013 Acc: 0.7290
# train bacteria Sensitivity: 0.5732 specificity: 0.8705
# train covid Sensitivity: 0.9400 specificity: 0.9762
# train influenza Sensitivity: 0.5581 specificity: 0.8448
# train normal Sensitivity: 0.8571 specificity: 0.9459
# val Loss: 0.6185 Acc: 0.7603
# val bacteria Sensitivity: 0.9219 specificity: 0.7980
# val covid Sensitivity: 0.9661 specificity: 0.9760
# val influenza Sensitivity: 0.2800 specificity: 0.9844
# val normal Sensitivity: 0.9565 specificity: 0.9242
#
# Epoch 9/19
# ----------
# train Loss: 0.5545 Acc: 0.7567
# train bacteria Sensitivity: 0.6656 specificity: 0.8694
# train covid Sensitivity: 0.9400 specificity: 0.9881
# train influenza Sensitivity: 0.5355 specificity: 0.8699
# train normal Sensitivity: 0.8970 specificity: 0.9470
# val Loss: 0.5901 Acc: 0.7828
# val bacteria Sensitivity: 0.9062 specificity: 0.8374
# val covid Sensitivity: 0.9831 specificity: 0.9712
# val influenza Sensitivity: 0.3733 specificity: 0.9740
# val normal Sensitivity: 0.9420 specificity: 0.9293
#
# Epoch 10/19
# ----------
# train Loss: 0.5925 Acc: 0.7388
# train bacteria Sensitivity: 0.6083 specificity: 0.8793
# train covid Sensitivity: 0.9567 specificity: 0.9773
# train influenza Sensitivity: 0.5613 specificity: 0.8481
# train normal Sensitivity: 0.8405 specificity: 0.9459
# val Loss: 0.6322 Acc: 0.7566
# val bacteria Sensitivity: 0.8906 specificity: 0.8177
# val covid Sensitivity: 0.9831 specificity: 0.9663
# val influenza Sensitivity: 0.2800 specificity: 0.9792
# val normal Sensitivity: 0.9565 specificity: 0.9141
#
# Epoch 11/19
# ----------
# train Loss: 0.5698 Acc: 0.7478
# train bacteria Sensitivity: 0.6210 specificity: 0.8814
# train covid Sensitivity: 0.9433 specificity: 0.9805
# train influenza Sensitivity: 0.5484 specificity: 0.8667
# train normal Sensitivity: 0.8904 specificity: 0.9340
# val Loss: 0.5346 Acc: 0.7566
# val bacteria Sensitivity: 0.7031 specificity: 0.8522
# val covid Sensitivity: 0.9831 specificity: 0.9856
# val influenza Sensitivity: 0.4400 specificity: 0.9062
# val normal Sensitivity: 0.9565 specificity: 0.9293
#
# Epoch 12/19
# ----------
# train Loss: 0.5402 Acc: 0.7649
# train bacteria Sensitivity: 0.6592 specificity: 0.8814
# train covid Sensitivity: 0.9433 specificity: 0.9751
# train influenza Sensitivity: 0.5742 specificity: 0.8765
# train normal Sensitivity: 0.8937 specificity: 0.9524
# val Loss: 0.5591 Acc: 0.7828
# val bacteria Sensitivity: 0.8281 specificity: 0.8670
# val covid Sensitivity: 1.0000 specificity: 0.9615
# val influenza Sensitivity: 0.4267 specificity: 0.9479
# val normal Sensitivity: 0.9420 specificity: 0.9343
#
# Epoch 13/19
# ----------
# train Loss: 0.5300 Acc: 0.7755
# train bacteria Sensitivity: 0.6497 specificity: 0.8869
# train covid Sensitivity: 0.9500 specificity: 0.9719
# train influenza Sensitivity: 0.6097 specificity: 0.8863
# train normal Sensitivity: 0.9037 specificity: 0.9545
# val Loss: 0.5416 Acc: 0.7715
# val bacteria Sensitivity: 0.7812 specificity: 0.8522
# val covid Sensitivity: 0.9661 specificity: 0.9856
# val influenza Sensitivity: 0.4400 specificity: 0.9323
# val normal Sensitivity: 0.9565 specificity: 0.9242
#
# Epoch 14/19
# ----------
# train Loss: 0.4979 Acc: 0.7935
# train bacteria Sensitivity: 0.6815 specificity: 0.8990
# train covid Sensitivity: 0.9567 specificity: 0.9838
# train influenza Sensitivity: 0.6226 specificity: 0.8929
# train normal Sensitivity: 0.9236 specificity: 0.9481
# val Loss: 0.5422 Acc: 0.7715
# val bacteria Sensitivity: 0.8125 specificity: 0.8424
# val covid Sensitivity: 0.9661 specificity: 0.9856
# val influenza Sensitivity: 0.4133 specificity: 0.9479
# val normal Sensitivity: 0.9565 specificity: 0.9192
#
# Epoch 15/19
# ----------
# train Loss: 0.5260 Acc: 0.7649
# train bacteria Sensitivity: 0.6083 specificity: 0.8968
# train covid Sensitivity: 0.9467 specificity: 0.9795
# train influenza Sensitivity: 0.6032 specificity: 0.8656
# train normal Sensitivity: 0.9136 specificity: 0.9437
# val Loss: 0.5160 Acc: 0.7566
# val bacteria Sensitivity: 0.7031 specificity: 0.8621
# val covid Sensitivity: 0.9831 specificity: 0.9760
# val influenza Sensitivity: 0.4533 specificity: 0.9010
# val normal Sensitivity: 0.9420 specificity: 0.9343
#
# Epoch 16/19
# ----------
# train Loss: 0.4764 Acc: 0.7984
# train bacteria Sensitivity: 0.7070 specificity: 0.8902
# train covid Sensitivity: 0.9533 specificity: 0.9827
# train influenza Sensitivity: 0.6226 specificity: 0.8874
# train normal Sensitivity: 0.9203 specificity: 0.9697
# val Loss: 0.5413 Acc: 0.7753
# val bacteria Sensitivity: 0.7812 specificity: 0.8621
# val covid Sensitivity: 1.0000 specificity: 0.9760
# val influenza Sensitivity: 0.4267 specificity: 0.9427
# val normal Sensitivity: 0.9565 specificity: 0.9192
#
# Epoch 17/19
# ----------
# train Loss: 0.5009 Acc: 0.7714
# train bacteria Sensitivity: 0.6019 specificity: 0.8968
# train covid Sensitivity: 0.9767 specificity: 0.9881
# train influenza Sensitivity: 0.6226 specificity: 0.8634
# train normal Sensitivity: 0.8970 specificity: 0.9459
# val Loss: 0.5743 Acc: 0.7790
# val bacteria Sensitivity: 0.8281 specificity: 0.8621
# val covid Sensitivity: 1.0000 specificity: 0.9760
# val influenza Sensitivity: 0.4000 specificity: 0.9635
# val normal Sensitivity: 0.9565 specificity: 0.9040
#
# Epoch 18/19
# ----------
# train Loss: 0.4820 Acc: 0.7878
# train bacteria Sensitivity: 0.6815 specificity: 0.8836
# train covid Sensitivity: 0.9600 specificity: 0.9838
# train influenza Sensitivity: 0.6000 specificity: 0.8929
# train normal Sensitivity: 0.9203 specificity: 0.9556
# val Loss: 0.5391 Acc: 0.7715
# val bacteria Sensitivity: 0.7812 specificity: 0.8621
# val covid Sensitivity: 1.0000 specificity: 0.9712
# val influenza Sensitivity: 0.4267 specificity: 0.9271
# val normal Sensitivity: 0.9420 specificity: 0.9343
#
# Epoch 19/19
# ----------
# train Loss: 0.4802 Acc: 0.7845
# train bacteria Sensitivity: 0.6561 specificity: 0.8771
# train covid Sensitivity: 0.9600 specificity: 0.9870
# train influenza Sensitivity: 0.6032 specificity: 0.8863
# train normal Sensitivity: 0.9302 specificity: 0.9610
# val Loss: 0.5186 Acc: 0.7828
# val bacteria Sensitivity: 0.8125 specificity: 0.8522
# val covid Sensitivity: 0.9661 specificity: 0.9856
# val influenza Sensitivity: 0.4667 specificity: 0.9271
# val normal Sensitivity: 0.9420 specificity: 0.9444
#
# Training complete in 11m 54s
# Best val Acc: 0.782772

# %%
class_names
# Out:
# ['bacteria', 'covid', 'influenza', 'normal']

# %%
acc
# Out:
# [tensor(0.3829, device='cuda:0', dtype=torch.float64),
#  tensor(0.5918, device='cuda:0', dtype=torch.float64),
#  tensor(0.5812, device='cuda:0', dtype=torch.float64),
#  tensor(0.6180, device='cuda:0', dtype=torch.float64),
#  tensor(0.6343, device='cuda:0', dtype=torch.float64),
#  tensor(0.6142, device='cuda:0', dtype=torch.float64),
#  tensor(0.6555, device='cuda:0', dtype=torch.float64),
#  tensor(0.7004, device='cuda:0', dtype=torch.float64),
#  tensor(0.6702, device='cuda:0', dtype=torch.float64),
#  tensor(0.6479, device='cuda:0', dtype=torch.float64),
#  tensor(0.6906, device='cuda:0', dtype=torch.float64),
#  tensor(0.7566, device='cuda:0', dtype=torch.float64),
#  tensor(0.6669, device='cuda:0', dtype=torch.float64),
#  tensor(0.4719, device='cuda:0', dtype=torch.float64),
#  tensor(0.7200, device='cuda:0', dtype=torch.float64),
#  tensor(0.7341, device='cuda:0', dtype=torch.float64),
#  tensor(0.7290, device='cuda:0', dtype=torch.float64),
#  tensor(0.7603, device='cuda:0', dtype=torch.float64),
#  tensor(0.7567, device='cuda:0', dtype=torch.float64),
#  tensor(0.7828, device='cuda:0', dtype=torch.float64),
#  tensor(0.7388, device='cuda:0', dtype=torch.float64),
#  tensor(0.7566, device='cuda:0', dtype=torch.float64),
#  tensor(0.7478, device='cuda:0', dtype=torch.float64),
#  tensor(0.7566, device='cuda:0', dtype=torch.float64),
#  tensor(0.7649, device='cuda:0', dtype=torch.float64),
#  tensor(0.7828, device='cuda:0', dtype=torch.float64),
#  tensor(0.7755, device='cuda:0', dtype=torch.float64),
#  tensor(0.7715, device='cuda:0', dtype=torch.float64),
#  tensor(0.7935, device='cuda:0', dtype=torch.float64),
#  tensor(0.7715, device='cuda:0', dtype=torch.float64),
#  tensor(0.7649, device='cuda:0', dtype=torch.float64),
#  tensor(0.7566, device='cuda:0', dtype=torch.float64),
#  tensor(0.7984, device='cuda:0', dtype=torch.float64),
#  tensor(0.7753, device='cuda:0', dtype=torch.float64),
#  tensor(0.7714, device='cuda:0', dtype=torch.float64),
#  tensor(0.7790, device='cuda:0', dtype=torch.float64),
#  tensor(0.7878, device='cuda:0', dtype=torch.float64),
#  tensor(0.7715, device='cuda:0', dtype=torch.float64),
#  tensor(0.7845, device='cuda:0', dtype=torch.float64),
#  tensor(0.7828, device='cuda:0', dtype=torch.float64)]

# %%
torch.save('acc_unpretrained.csv', acc.np() )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-d1a4bd07f599> in <module>
# ----> 1 torch.save('acc_unpretrained.csv', acc.np() )
#
# AttributeError: 'list' object has no attribute 'np'

# %%
acc.numpy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-5e41fbf91a96> in <module>
# ----> 1 acc.numpy()
#
# AttributeError: 'list' object has no attribute 'numpy'
